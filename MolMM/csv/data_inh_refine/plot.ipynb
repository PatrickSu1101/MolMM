# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv(os.path.join('./','clean_inhibitors.csv'))

# %%
# Plotting the distribution of 'column1'
plt.figure(figsize=(10, 6))
sns.distplot(df['mean'], kde=True, bins=100)
plt.title('Distribution of Column 1')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
y = df['mean'].to_numpy()

# %%
sum(y < 15), sum((y >= 15) & (y <= 100)), sum(y > 100)
# Out:
# (1484, 452, 82)

# %%
min(y), max(y)
# Out:
# (0.0006, 481.0)

# %%
count = {}
for i in range(50):
    count[i] = 0
    
for data in df['mean']:
    count[data//10]+=1

# %%
import numpy as np

# %%
def plot(data):
# Plotting the distribution of 'column1'
    plt.figure(figsize=(10, 6))
    sns.distplot(data, kde=True, bins=50)
    plt.title('Distribution of Column 1')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.show()

# %%
y = y[y<15]

# %%
plot(y/15)

# %%
mean = y.mean()
std = y.std()

# %%
mean,std
# Out:
# (2.9702299852500746, 3.638307209082117)

# %%
y_ceil = np.ceil(y*10)/10

# %%
y_ceil
# Out:
# array([ 0.1,  0.1,  0.1, ..., 14.7, 14.9, 14.9])

# %%
plot(y_ceil)

# %%
standardize_data(y_ceil)
# Out:
# -0.9667406261906363 3.955646697595195
# -7.660838121402698e-17 1.2064352740160702

# %%
y_log = np.log(y_ceil)/np.log(10)

# %%
plot(y_log)

# %%
def standardize_data(y_log):
    mean = y_log.mean()
    std = y_log.std()
    stdy = (y_log-mean)/std
    print(mean,std)
    plot(stdy)

# %%
standardize_data(y)
# Out:
# 2.9702299852500746 3.638307209082117
